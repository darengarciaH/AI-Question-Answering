# %%
# %pip install html5lib
# %pip install bs4
# %pip install tabula-py
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tabula import read_pdf
import pandas as pd
import os
from bs4 import BeautifulSoup

# %%
PARENT_DIR= "/Users/darengarcia/Desktop/analysis-projects/AI-Question-Answering/Data/"

# %%
# USDA AI Use Cases
usda_df= pd.read_csv(PARENT_DIR + "2023 Public Inventory of AI Use Cases - USDA.csv")
usda_df= usda_df.rename(columns= {
    'Date Initiated, If Applicable' : 'Date Initiated (if applicable)',
    'Date when Development and/or Acquisition began, If Applicable' : 'Date when Development and/or Acquisition began (if applicable)',
    'Date Implemented, If Applicable' : 'Date Implemented (if applicable)',
    'Explanation for inconsistencies with EO 13960': 'EO 13960 Explanation',
    'What specific AI techniques were used?' : 'AI Techniques Used',
    'Where did/does the training data originate?' : 'Training Data Origins',
    'Does the agency have access to the code associated with this AI use case?': 'Use Case Code Accessible',
    'If the source code is publicly available, provide the link.': 'Source Code Public Link',
    'Is the agency able to conduct ongoing testing on the code?': 'Agency Able To Test Code',
    'Is the agency able to monitor and/or audit performance?' : 'Agency Able To Monitor/Audit'
})
usda_df= usda_df[['Use Case Name',
 'Summary of Use Case',
 'Agency',
 'Bureau / Department',
 'Use Case ID',
 'Stage of System Development Life Cycle',
 'Date Initiated (if applicable)',
 'Date when Development and/or Acquisition began (if applicable)',
 'Date Implemented (if applicable)',
 'Developer Information',
 'Consistent with EO 13960?',
 'EO 13960 Explanation',
 'AI Techniques Used',
 'Training Data Origins',
 'Use Case Code Accessible',
 'Source Code Public Link',
 'Agency Able To Test Code',
 'Agency Able To Monitor/Audit'
]]
usda_df["Agency"]= "United States Department of Agriculture"
usda_df.head()
# Out:
#                                        Use Case Name  \
# 0                                4% Repair Dashboard
# 1                                ARS Project Mapping
# 2                             NAL Automated indexing
# 3  Predictive modeling of invasive pest species a...
# 4   Detection of pre-symptomatic HLB infected citrus
#
#                                  Summary of Use Case  \
# 0  The model reviews the descriptions of expenses...
# 1  NLP of research project plans including term a...
# 2  Cogito (vendor) software, uses AI for automate...
# 3  Macine learning algorithms are used to develop...
# 4  Identify pixels with HLB infection signature i...
#
#                                     Agency Bureau / Department Use Case ID  \
# 0  United States Department of Agriculture                 ARS      USDA-1
# 1  United States Department of Agriculture                 ARS      USDA-2
# 2  United States Department of Agriculture                 ARS      USDA-3
# ...

# %%
# Dept of Ed AI Use Case
ed_df= pd.read_csv(PARENT_DIR + "ed-rpa-ai-inventory.csv")
ed_df.columns = ed_df.iloc[0]
ed_df= ed_df.iloc[1:2]
ed_df= ed_df.reset_index()
ed_df= ed_df.rename(columns={'Short Description of Project': 'Summary of Use Case',
                      'Artificial Intelligence Project Name': 'Use Case Name',
                      'Developer information': 'Developer Information',
                      'Implementation Stage' : 'Stage of System Development Life Cycle'})
ed_df["Agency"]= "Department of Education"
ed_df= ed_df[['Use Case Name', 'Summary of Use Case', 'Agency', 'Use Type',
       'Stage of System Development Life Cycle', 'Developer Information',
       'Total Lifecycle Estimated Cost of Project', 'FY21 Expenditure',
       'FY20 Expenditure']]
ed_df.head()
# Out:
# 0 Use Case Name                                Summary of Use Case  \
# 0         Aidan  FSA’s virtual assistant uses natural language ...
#
# 0                   Agency                        Use Type  \
# 0  Department of Education  Public services and engagement
#
# 0 Stage of System Development Life Cycle Developer Information  \
# 0                  Continuous Monitoring              contract
#
# 0 Total Lifecycle Estimated Cost of Project           FY21 Expenditure  \
# 0                               $9,387,648   $               2,575,083
#
# 0           FY20 Expenditure
# 0  $               1,991,591

# %%
# Social Security AI Use Case
ssa_df= pd.read_csv(PARENT_DIR + "SSA-AI-Inv.csv")
ssa_df["Agency"]= "Social Security Administration"
ssa_df= ssa_df[['Use Case Name', 'Summary of Use Case', 'Agency', 'Bureau / Department']]
ssa_df.head()
# Out:
#                                        Use Case Name  \
# 0                                            Insight
# 1  Intelligent Medical Language Analysis Generati...
# 2             Duplicate Identification Process (DIP)
# 3                 Handwriting recognition from forms
# 4             Modernized Development Worksheet (MDW)
#
#                                  Summary of Use Case  \
# 0  Insight is decision support software used by h...
# 1  IMAGEN is an IT Modernization Disability Analy...
# 2  Duplicate Identification Process's (DIP's) obj...
# 3  AI performs OCR against handwritten entries on...
# 4  This process uses AI to review textual data th...
#
#                            Agency  \
# 0  Social Security Administration
# 1  Social Security Administration
# 2  Social Security Administration
# 3  Social Security Administration
# 4  Social Security Administration
#
#                                  Bureau / Department
# ...

# %%
# Health and Human Services AI
hhs_df= pd.read_csv(PARENT_DIR + "hhs-ai-use-cases-2023-public-inventory.csv")
hhs_df= hhs_df[['Use Case Name', 'Summary of Use Case', 'Agency', 'Bureau / Department',
       'Stage of System Development Life Cycle', 'Date Initiated',
       'Date when Development and/or Acquisition began (if applicable)',
       'Date Implemented (if applicable)', 'Contact Email',
       'Developer Information', 'Consistent with EO 13960?']]
hhs_df= hhs_df.rename(columns={"Agency": "HHS Agency", 'Date Initiated': 'Date Initiated (if applicable)'})
hhs_df["Agency"]= "Health and Human Services"
hhs_df["Bureau / Department"]= hhs_df["HHS Agency"] + ": " + hhs_df["Bureau / Department"]
hhs_df= hhs_df[['Use Case Name', 'Summary of Use Case', 'Agency', 'Bureau / Department',
       'HHS Agency',
       'Stage of System Development Life Cycle',
       'Date Initiated (if applicable)',
       'Date when Development and/or Acquisition began (if applicable)',
       'Date Implemented (if applicable)', 'Contact Email',
       'Developer Information', 'Consistent with EO 13960?']]
hhs_df.head()
# Out:
#                                        Use Case Name  \
# 0           Information Gateway OneReach Application
# 1  Artificial Intelligence-based Deduplication Al...
# 2  Information Visualization Platform (InfoViP) t...
# 3  Opioid Data Warehouse Term Identification and ...
# 4  Community Level Opioid Use Dynamics Modeling a...
#
#                                  Summary of Use Case  \
# 0  The Information Gateway hotline connects to a ...
# 1  The deduplication algorithm is applied to nonp...
# 2  Developed the Information Visualization Platfo...
# 3  The Term Identification and Novel Synthetic Op...
# 4  The OUD project leverages artificial intellige...
#
#                       Agency  \
# 0  Health and Human Services
# 1  Health and Human Services
# 2  Health and Human Services
# 3  Health and Human Services
# 4  Health and Human Services
#
#                                  Bureau / Department HHS Agency  \
# 0                         ACF: ACF Children's Bureau        ACF
# ...

# %%
# National Archives and Records Administration AI
nara_df= pd.read_csv(PARENT_DIR + "2023-agency-inventory-of-ai-use-cases-public-nara.csv")
nara_df.columns = nara_df.iloc[0]
nara_df= nara_df.iloc[1:12]
nara_df= nara_df.rename(columns={'1A.\nAI use case name': 'Use Case Name',
                                 '1B.\nAgency with AI use case': 'Agency',
                                 '\nProvide a short summary (200 words max) of what the AI does. Include a high-level description of system inputs and outputs. ': 'Summary of Use Case',
                                 'Optional Note Field: To clarify 1B or to provide additional information (e.g. Agency co-development) ': 'Optional Note Field',
                                 '2A.\nLast Name, First Name': 'Contact Name',
                                 '1C.\nOffice with AI use case': 'Bureau / Department',
                                 '2B.\nEmail Address': 'Contact Email',
                                 '2C.\nAdditional point of contact name and email address': 'Additional Contact Name and Email',
                                 '4A.\nWhat stage of production is the AI in?': 'Stage of System Development Life Cycle',
                                 '4B.\nAdditional comments related to lifecycle stage.': 'Additional Life Cycle Comments',
                                 '\nWhat specific AI techniques were used?' : 'AI Techniques Used',
                                 '6A.\nDid/does the agency train this AI use case?': 'Agency Training Used',
                                 '6B.\nIf yes - Where did/does the training data originate?': 'Training Data Origins',
                                 '6C.\nIs the training data, the validation data, and/or test data included in the enterprise data inventory? ': 'Included In Enterprise Inventory',
                                 '6D.\nIf data is publicly available, provide link. ': 'Public Data Link',
                                 '7A.\nDoes the agency have access to the code associate with this AI use case?': 'Use Case Code Accessible',
                                 '7B.\nIf yes, is the code included in the agency source code inventory (e.g. Code.gov)?': 'Code Included In Agency Inventory',
                                 '7C.\n If the source code is publicly available, provide the link.': 'Source Code Public Link',
                                 '7D.\nIs the agency able to conduct ongoing testing on the code?': 'Agency Able To Test Code',
                                 '7E.\nIs the agency able to monitor and/or audit performance? ': 'Agency Able To Monitor/Audit',
                                 '\nProvide the name of the Information System (e.g. FISMA system name) associated with the AI use case.': 'FISMA System Name',
                                 '9A.\nShould this use case be withheld from the public inventory? If yes, the use case will only be shared in the internal government inventory.  ': 'Withhold Use Case',
                                 '9B.\n If the answer to 9A is yes, provide an explanation (this explanation will be included in the internal government inventory).': 'Explanation To Withhold Use Case'
                                 })
nara_df["Agency"]= "National Archives and Records Administration"
nara_df= nara_df[['Use Case Name',
                  'Summary of Use Case',
                  'Agency',
                  'Optional Note Field',
                  'Bureau / Department',
                  'Contact Name',
                  'Contact Email',
                  'Additional Contact Name and Email',
                  'Stage of System Development Life Cycle',
                  'Additional Life Cycle Comments',
                  'AI Techniques Used',
                  'Agency Training Used',
                  'Training Data Origins',
                  'Included In Enterprise Inventory',
                  'Public Data Link',
                  'Use Case Code Accessible',
                  'Code Included In Agency Inventory',
                  'Source Code Public Link',
                  'Agency Able To Test Code',
                  'Agency Able To Monitor/Audit',
                  'FISMA System Name',
                  'Withhold Use Case',
                  'Explanation To Withhold Use Case']]
nara_df.head()
# Out:
# 0                                      Use Case Name  \
# 1  AI Pilot Project to Screen and Flag for Person...
# 2  AI Pilot for National Declassification Center ...
# 3  Freedom of Information Act (FOIA) Discovery AI...
# 4  Auto-fill of Descriptive Metadata for Archival...
# 5  Automated Data Discovery and Classification Pi...
#
# 0                                Summary of Use Case  \
# 1  The NARA Information Service (I) team collabor...
# 2  The National Declassification Center (NDC) at ...
# 3  NARA would like to utilize various AI techniqu...
# 4  Archival descriptions or Self-describing recor...
# 5  NARA is planning to conduct a future pilot to ...
#
# 0                                        Agency  \
# 1  National Archives and Records Administration
# 2  National Archives and Records Administration
# 3  National Archives and Records Administration
# 4  National Archives and Records Administration
# 5  National Archives and Records Administration
#
# ...

# %%
# USAID AI Use Cases
usaid_df= pd.read_csv(PARENT_DIR + "2023 Agency Inventory of AI Use Cases - USAID.csv")
usaid_df= usaid_df.iloc[0:14]
usaid_df= usaid_df.rename(columns= {'Date Initiated': 'Date Initiated (if applicable)',
       '(Optional) Explanation for inconsistencies with EO 13960': 'EO 13960 Explanation',
       '(Optional) What specific AI techniques were used?': 'AI Techniques Used',
       '(Optional) Where did/does the training data originate?': 'Training Data Origins',
       '(Optional) Does the agency have access to the code associated with the AI use case?': 'Use Case Code Accessible',
       '(Optional) If the source code is publicly available, provide link.': 'Source Code Public Link',
       '(Optional) Is the agency able to conduct ongoing testing on the code?': 'Agency Able To Test Code',
       '(Optional) Is the agency able to monitor and/or audit performance?' : 'Agency Able To Monitor/Audit'
})
usaid_df= usaid_df[['Use Case Name', 'Summary of Use Case', 'Agency', 'Bureau / Department', 'Use Case ID',
       'Stage of System Development Life Cycle',
       'Date Initiated (if applicable)',
       'Date when Development and/or Acquisition began (if applicable)',
       'Date Implemented (if applicable)', 'Contact Name', 'Contact Email',
       'Developer Information', 'Consistent with EO 13960?',
       'EO 13960 Explanation',
       'AI Techniques Used',
       'Training Data Origins',
       'Use Case Code Accessible',
       'Source Code Public Link',
       'Agency Able To Test Code',
       'Agency Able To Monitor/Audit']]
usaid_df.head()
# Out:
#                                        Use Case Name  \
# 0                  Media Early Warning System (MEWS)
# 1               Gender differentiated credit scoring
# 2  Using ML for predicting treatment interruption...
# 3                         Machine Learning for Peace
# 4  Long-term impacts of land-use/land-cover dynam...
#
#                                  Summary of Use Case  \
# 0  To detect narratives and trends in social medi...
# 1  University of California, Berkeley, is buildin...
# 2  Using data from USAID funded Strengthening Int...
# 3  Objective 1 under the Illuminating New Solutio...
# 4  For water supply, semi-arid Botswana relies on...
#
#                                       Agency  \
# 0  U.S. Agency for International Development
# 1  U.S. Agency for International Development
# 2  U.S. Agency for International Development
# 3  U.S. Agency for International Development
# 4  U.S. Agency for International Development
#
# ...

# %%
# OPM AI Use Cases
opm_df= pd.read_csv(PARENT_DIR + "2023-agency-inventory-of-ai-use-cases-opm.csv")
opm_df= opm_df.rename(columns= {'Date Initiated': 'Date Initiated (if applicable)',
       '(Optional) Explanation for inconsistencies with EO 13960': 'EO 13960 Explanation',
       '(Optional) What specific AI techniques were used?': 'AI Techniques Used',
       '(Optional) Where did/does the training data originate?': 'Training Data Origins',
       '(Optional) Does the agency have access to the code associated with the AI use case?': 'Use Case Code Accessible',
       '(Optional) If the source code is publicly available, provide link.': 'Source Code Public Link',
       '(Optional) Is the agency able to conduct ongoing testing on the code?': 'Agency Able To Test Code',
       '(Optional) Is the agency able to monitor and/or audit performance?' : 'Agency Able To Monitor/Audit'
})
opm_df= opm_df[['Use Case Name', 'Summary of Use Case', 'Agency', 'Bureau / Department', 'Use Case ID',
       'Stage of System Development Life Cycle',
       'Date Initiated (if applicable)',
       'Date when Development and/or Acquisition began (if applicable)',
       'Date Implemented (if applicable)', 'Contact Email',
       'Developer Information', 'Consistent with EO 13960?',
       'EO 13960 Explanation',
       'AI Techniques Used',
       'Training Data Origins',
       'Use Case Code Accessible',
       'Source Code Public Link',
       'Agency Able To Test Code',
       'Agency Able To Monitor/Audit']]
opm_df.head()
# Out:
#                            Use Case Name  \
# 0  Skills matching on Open Opportunities
# 1            Similar Job Recommendations
# 2        Human Resource Apprentice (HRA)
# 3      Retirement Services (RS) Chat Bot
#
#                                  Summary of Use Case  \
# 0  The website uses Skills engine, a third party ...
# 1  USAJOBS is planning to use natural language pr...
# 2  Evaluate the technical feasibility, validity, ...
# 3  A chatbot is a computer program that uses arti...
#
#                            Agency        Bureau / Department Use Case ID  \
# 0  Office of Personnel Management                HRS/USAJOBS       OPM-1
# 1  Office of Personnel Management                HRS/USAJOBS       OPM-2
# 2  Office of Personnel Management  HRS/FSC/ASMG & OCIO/FITBS       OPM-3
# 3  Office of Personnel Management                      RS/RO       OPM-4
#
#   Stage of System Development Life Cycle Date Initiated (if applicable)  \
# ...

# %%
# Department of Homeland Security AI Use Cases
dhs_df= pd.read_csv(PARENT_DIR + "23_0726_ocio_dhs-inventory-of-ai-use-cases.csv")
dhs_df= dhs_df.rename(columns= {'Date Initiated, If Applicable': 'Date Initiated (if applicable)',
                            'Date when Development and/or Acquisition began, if  Applicable' : 'Date when Development and/or Acquisition began (if applicable)',
                            'Date Implemented, If Applicable' : 'Date Implemented (if applicable)',
                            'Explanation for inconsistencies with EO 13960': 'EO 13960 Explanation',
                            'What specific AI techniques were used?' : 'AI Techniques Used',
                            'Where did/does the training data originate?' : 'Training Data Origins',
                            'Does the agency have access to the code associated with the AI use case?': 'Use Case Code Accessible',
                            'If the source code is publicly available, provide link.': 'Source Code Public Link',
                            'Is the agency able to conduct ongoing testing on the code?': 'Agency Able To Test Code',
                            'Is the agency able to monitor and/or audit performance?' : 'Agency Able To Monitor/Audit'
})
dhs_df= dhs_df[['Use Case Name', 'Summary of Use Case', 'Agency', 'Bureau / Department', 'Use Case ID',
       'Stage of System Development Life Cycle',
       'Date Initiated (if applicable)',
       'Date when Development and/or Acquisition began (if applicable)',
       'Date Implemented (if applicable)',
       'Developer Information', 'Consistent with EO 13960?',
       'AI Techniques Used',
       'Training Data Origins',
       'Use Case Code Accessible',
       'Source Code Public Link',
       'Agency Able To Test Code',
       'Agency Able To Monitor/Audit']]
dhs_df.head()
# Out:
#                                       Use Case Name  \
# 0                            Normalization Services
# 1  Advanced Analytic Enabled Forensic Investigation
# 2                 Advanced Network Anomaly Alerting
# 3                         AI Curated Synthetic Data
# 4           AI for Autonomous Situational Awareness
#
#                                  Summary of Use Case  \
# 0  HSI uses Artificial Intelligence to verify, va...
# 1  CISA deploys forensic specialists to analyze c...
# 2  Threat hunting and Security Operations Center ...
# 3  AI Curated Synthetic Data creates synthetic da...
# 4  The AI for autonomous situational awareness sy...
#
#                             Agency  \
# 0  Department of Homeland Security
# 1  Department of Homeland Security
# 2  Department of Homeland Security
# 3  Department of Homeland Security
# 4  Department of Homeland Security
#
#                                 Bureau / Department Use Case ID  \
# ...

# %%
# Department of Interior AI Use Cases
doi_df= pd.read_csv(PARENT_DIR + "2023-agency-inventory-of-ai-use-cases-for-doigovdata.csv")
doi_df= doi_df.rename(columns= {'Date Initiated': 'Date Initiated (if applicable)',
       '(Optional) Explanation for inconsistencies with EO 13960': 'EO 13960 Explanation',
       '(Optional) What specific AI techniques were used?': 'AI Techniques Used',
       '(Optional) Where did/does the training data originate?': 'Training Data Origins',
       '(Optional) Does the agency have access to the code associated with the AI use case?': 'Use Case Code Accessible',
       '(Optional) If the source code is publicly available, provide link.': 'Source Code Public Link',
       '(Optional) Is the agency able to conduct ongoing testing on the code?': 'Agency Able To Test Code',
       '(Optional) Is the agency able to monitor and/or audit performance?' : 'Agency Able To Monitor/Audit'
})
doi_df= doi_df[['Use Case Name', 'Summary of Use Case', 'Agency', 'Bureau / Department', 'Use Case ID',
       'Stage of System Development Life Cycle',
       'Date Initiated (if applicable)',
       'Date when Development and/or Acquisition began (if applicable)',
       'Date Implemented (if applicable)',
       'Developer Information', 'Consistent with EO 13960?',
       'AI Techniques Used',
       'Training Data Origins',
       'Use Case Code Accessible',
       'Source Code Public Link',
       'Agency Able To Test Code',
       'Agency Able To Monitor/Audit']]
doi_df.head()
# Out:
#                                        Use Case Name  \
# 0  Seasonal/Temporary Wetland/Floodplain Delineat...
# 1  Data Driven Sub-Seasonal Forecasting of Temper...
# 2                 Data Driven Streamflow Forecasting
# 3           Sustained Casing Pressure Identification
# 4                Well Activity Report Classification
#
#                                  Summary of Use Case  \
# 0  Reclamation was interested in determining if r...
# 1  Reclamation has run 2, year-long prize competi...
# 2  Reclamation, along with partners from the CEAT...
# 3  Well casing pressure requests are submitted to...
# 4  Researching the use of self-supervised and sup...
#
#                        Agency Bureau / Department Use Case ID  \
# 0  Department of the Interior                 BOR      DOI-59
# 1  Department of the Interior                 BOR      DOI-57
# 2  Department of the Interior                 BOR      DOI-58
# 3  Department of the Interior                BSEE      DOI-63
# ...

# %%
# Department of Transportation AI Use Cases
dot_df= pd.read_csv(PARENT_DIR + "Department_of_Transportation_Inventory_of_Artificial_Intelligence_Use_Cases.csv")
dot_df= dot_df.rename(columns={'AI Use Case Name': 'Use Case Name',
                      'Agency With AI Use Case': 'Agency',
                      'Summary': 'Summary of Use Case',
                      'Office With AI Use Case': 'Bureau / Department',
                      'Current Stage Of Production': 'Stage of System Development Life Cycle',
                      'Lifecycle Stage Additional Comments': 'Additional Life Cycle Comments'
})
dot_df= dot_df[['Use Case Name', 'Summary of Use Case', 'Agency',
       'Bureau / Department', 'Optional Note Field',
       'Stage of System Development Life Cycle', 'Additional Life Cycle Comments',
       'AI Techniques Used', 'Agency Training Used', 'Training Data Origins',
       'Included In Enterprise Inventory', 'Public Data Link',
       'Use Case Code Accessible', 'Code Included In Agency Inventory',
       'Source Code Public Link', 'Agency Able To Test Code',
       'Agency Able To Monitor/Audit', 'FISMA System Name',
       'Withhold Use Case', 'Explanation To Withhold Use Case']]
dot_df["Agency"]= "Department of Transportation"
dot_df.head()
# Out:
#                                       Use Case Name  \
# 0                                          REDACTED
# 1  Automated Delay detection using voice processing
# 2                                          REDACTED
# 3                                          REDACTED
# 4                                          REDACTED
#
#                                  Summary of Use Case  \
# 0                                           REDACTED
# 1  In order to get a full accounting of delay, au...
# 2                                           REDACTED
# 3                                           REDACTED
# 4                                           REDACTED
#
#                          Agency Bureau / Department  \
# 0  Department of Transportation            REDACTED
# 1  Department of Transportation                 ATO
# 2  Department of Transportation            REDACTED
# 3  Department of Transportation            REDACTED
# 4  Department of Transportation            REDACTED
#
# ...

# %%
# GSA AI Use Cases
gsa_df= pd.read_csv(PARENT_DIR + "GSA-ai-inventory.csv")
gsa_df= gsa_df.rename(columns= {
    'Date Initiated' : 'Date Initiated (if applicable)',
    'Date when Development and/or Acquisition began, If Applicable' : 'Date when Development and/or Acquisition began (if applicable)',
    'Date Implemented, If\nApplicable' : 'Date Implemented (if applicable)',
    'Explanation for\r\ninconsistencies with EO 13960': 'EO 13960 Explanation',
    'What specific AI techniques\r\nwere used?' : 'AI Techniques Used',
    'Where did/does the training data originate?' : 'Training Data Origins',
    'Does the agency have access to the code associated with the AI use case?': 'Use Case Code Accessible',
    'If the source code is publicly available, provide link.': 'Source Code Public Link',
    'Is the agency able to conduct ongoing testing on the code?': 'Agency Able To Test Code',
    'Is the agency able to monitor and/or audit performance?' : 'Agency Able To Monitor/Audit'
})
gsa_df= gsa_df[['Use Case Name',
 'Summary of Use Case',
 'Agency',
 'Bureau / Department',
 'Use Case ID',
 'Stage of System Development Life Cycle',
 'Date Initiated (if applicable)',
 'Date when Development and/or Acquisition began (if applicable)',
 'Date Implemented (if applicable)',
 'Developer Information',
 'Consistent with EO 13960?',
 'EO 13960 Explanation',
 'AI Techniques Used',
 'Training Data Origins',
 'Use Case Code Accessible',
 'Source Code Public Link',
 'Agency Able To Test Code',
 'Agency Able To Monitor/Audit'
]]

gsa_df["Agency"]= "General Services Administration"
gsa_df.head()
# Out:
#                                        Use Case Name  \
# 0                     Solicitation Review Tool (SRT)
# 1                              Acquisition Analytics
# 2  City Pairs Program Ticket Forecast and Scenari...
# 3             Category Taxonomy Refinement Using NLP
# 4                         Key KPI Forecasts for GWCM
#
#                                  Summary of Use Case  \
# 0  The SRT intakes SAM.gov data for all Informati...
# 1  Takes Detailed Data on transactions and classi...
# 2  Takes segment-level City Pair Program air trav...
# 3  Uses token extraction from product description...
# 4  Takes monthly historical data for underlying c...
#
#                             Agency Bureau / Department Use Case ID  \
# 0  General Services Administration                 OGP   GS-230001
# 1  General Services Administration                 FAS   GS-230002
# 2  General Services Administration                 FAS   GS-230003
# ...

# %%
# Veterans Affairs
url= "https://www.research.va.gov/naii/ai-inventory.cfm"
va_df= pd.read_html(url, flavor='bs4')
va_df= va_df[1]
va_df.columns= va_df.iloc[0]
va_df= va_df.iloc[1:]
va_df= va_df.rename(columns={'AI use case name': 'Use Case Name', 'Summary': 'Summary of Use Case'})
va_df= va_df[['Use Case Name', 'Summary of Use Case']]
va_df["Agency"]= "Department of Veterans Affairs"
va_df.head()
# Out:
# 0                                     Use Case Name  \
# 1      Artificial Intelligence physical therapy app
# 2  Artificial intelligence coach in cardiac surgery
# 3                                           AI Cure
# 4                         Acute kidney injury (AKI)
# 5     Assessing lung function in health and disease
#
# 0                                Summary of Use Case  \
# 1  This app is a physical therapy support tool. I...
# 2  The artificial intelligence coach in cardiac s...
# 3  AICURE is a phone app that monitors adherence ...
# 4  This project, a collaboration with Google Deep...
# 5  Health professionals can use this artificial i...
#
# 0                          Agency
# 1  Department of Veterans Affairs
# 2  Department of Veterans Affairs
# 3  Department of Veterans Affairs
# 4  Department of Veterans Affairs
# 5  Department of Veterans Affairs

# %%
# Department of State
url= "https://www.state.gov/data-strategy/ai_inventory"
dos_df= pd.read_html(url, flavor='bs4')
dos_df= dos_df[0]
dos_df= dos_df.rename(columns={'AI USE CASE NAME': 'Use Case Name', 'PUBLIC SUMMARY': 'Summary of Use Case', 'BUREAU': 'Bureau / Department'})
dos_df["Agency"]= "Department of State"
dos_df= dos_df[['Use Case Name', 'Summary of Use Case', 'Agency', 'Bureau / Department']]
dos_df.head()
# Out:
#                                        Use Case Name  \
# 0               Facebook Ad Test Optimization System
# 1             Global Audience Segmentation Framework
# 2  Machine-Learning Assisted Measurement and Eval...
# 3                                 GPATools and GPAIX
# 4  NLP for Foreign Assistance Appropriations Anal...
#
#                                  Summary of Use Case               Agency  \
# 0  GPA’s production media collection and analysis...  Department of State
# 1  A prototype system that collects and analyzes ...  Department of State
# 2  GPA’s production system for collecting, analyz...  Department of State
# 3  GPA’s production system for testing potential ...  Department of State
# 4  Natural language processing application for F/...  Department of State
#
#   Bureau / Department
# 0                 GPA
# 1                 GPA
# 2                 GPA
# 3                 GPA
# 4                   F

# %%
# Department of Labor
url= "https://www.dol.gov/agencies/odg/ai-inventory"
dol_df= pd.read_html(url, flavor='bs4')
dol_df= dol_df[0]
dol_df= dol_df.rename(columns={'﻿AI Use Case Name': 'Use Case Name',
                               'Stage of Development': 'Stage of System Development Life Cycle',
                               'AI Technique': 'AI Techniques Used'})
dol_df["Agency"]= "Department of Labor"
dol_df= dol_df[['Use Case Name', 'Summary of Use Case', 'Agency', 'Stage of System Development Life Cycle', 'AI Techniques Used']]
dol_df.head()
# Out:
#                                        Use Case Name  \
# 0  ﻿AI Use Case Name  Form Recognizer for Benefit...
# 1            ﻿AI Use Case Name  Language Translation
# 2             ﻿AI Use Case Name  Audio Transcription
# 3       ﻿AI Use Case Name  Text to Speech Conversion
# 4      ﻿AI Use Case Name  Claims Document Processing
#
#                                  Summary of Use Case               Agency  \
# 0  Summary of Use Case  Custom machine learning m...  Department of Labor
# 1  Summary of Use Case  Language translation of p...  Department of Labor
# 2  Summary of Use Case  Transcription of speech t...  Department of Labor
# 3  Summary of Use Case  Text to speech (Neural) f...  Department of Labor
# 4  Summary of Use Case  To identify if physician’...  Department of Labor
#
#             Stage of System Development Life Cycle  \
# 0  Stage of Development  Operation and Maintenance
# 1             Stage of Development  Implementation
# ...

# %%
#Environmental Protection Agency
summary1= "Prioritizing the potential risk posed to human health by chemicals requires tools that can estimate exposure from limited information. In this study, chemical structure and physicochemical properties were used to predict the probability that a chemical might be associated with any of four exposure pathways leading from sources-consumer (near-field), dietary, far-field industrial, and far-field pesticide-to the general population. The balanced accuracies of these source-based exposure pathway models range from 73 to 81%, with the error rate for identifying positive chemicals ranging from 17 to 36%. We then used exposure pathways to organize predictions from 13 different exposure models as well as other predictors of human intake rates. We created a consensus, meta-model using the Systematic Empirical Evaluation of Models framework in which the predictors of exposure were combined by pathway and weighted according to predictive ability for chemical intake rates inferred from human biomonitoring data for 114 chemicals. The consensus model yields an R2 of ∼0.8. We extrapolate to predict relevant pathway(s), median intake rate, and credible interval for 479 926 chemicals, mostly with minimal exposure information. This approach identifies 1880 chemicals for which the median population intake rates may exceed 0.1 mg/kg bodyweight/day, while there is 95% confidence that the median intake rate is below 1 μg/kg BW/day for 474572 compounds. "
summary2= "The records management technology team is using machine learning to predict the retention schedule for records. The machine learning model will be incorporated into a records management application to help users apply retention schedules when they submit new records. "
summary3= "EPA’s Office of Compliance, in partnership with the University of Chicago, built a proof-of-concept to improve enforcement of environmental regulations through facility inspections by the EPA and state partners. The resulting predictive analytics showed a 47% improvement of identifying violations of the Resource Conservation and Recovery Act. Consensus Modeling of Median Chemical Intake for the U.S. Population Based on Predictions of Exposure Pathways"

epa_df= pd.DataFrame({"Use Case Name": ["Use of random forest model to predict exposure pathways", "Records Categorization", "Enforcement Targeting"],
                      "Summary of Use Case": [summary1, summary2, summary3],
                      "Agency": ["U.S. Environmental Protection Agency", "U.S. Environmental Protection Agency", "U.S. Environmental Protection Agency"]
                     })
epa_df
# Out:
#                                        Use Case Name  \
# 0  Use of random forest model to predict exposure...
# 1                             Records Categorization
# 2                              Enforcement Targeting
#
#                                  Summary of Use Case  \
# 0  Prioritizing the potential risk posed to human...
# 1  The records management technology team is usin...
# 2  EPA’s Office of Compliance, in partnership wit...
#
#                                  Agency
# 0  U.S. Environmental Protection Agency
# 1  U.S. Environmental Protection Agency
# 2  U.S. Environmental Protection Agency

# %%
#Housing and Urban Development
summary1= "In March 2023, PD&R began a pilot project to analyze aspects of HUD's Consolidated Plans. HUD requires grantees of its formula block grant programs to submit Consolidated Plans, which are meant to identify and assess affordable housing and community development needs and market conditions. These plans are publicly available via HUD's website. HUD staff currently review these plans for compliance, but HUD lacks the capacity to do in-depth analysis of commonalities or trends contained within plans. This pilot project will explore creating a database and chat-bot that will enable HUD staff to query features of the nearly 1,000 active Consolidated Plans. This pilot exercise has the potential to inform grantees, technical assistance, and other programmatic tweaks, as well as inform how advanced data science tools can benefit our programs and operations."
hud_df= pd.DataFrame({"Use Case Name": ["Consolidated Plan Pilot Analysis"],
                     "Summary of Use Case": [summary1],
                     "Agency": ["Department of Housing and Urban Development"]})
hud_df.head()
# Out:
#                       Use Case Name  \
# 0  Consolidated Plan Pilot Analysis
#
#                                  Summary of Use Case  \
# 0  In March 2023, PD&R began a pilot project to a...
#
#                                         Agency
# 0  Department of Housing and Urban Development

# %%
# Department of Commerce
doc_df = pd.read_csv(PARENT_DIR + "DOC_AI_Use_Case_Inventory.csv")
doc_df= doc_df.drop(['Department of Commerce - Artificial Intelligence (AI) Use Case Inventory - 2022'], axis=1)
doc_df= doc_df.rename(columns={'Unnamed: 0': 'Use Case Name', 'Unnamed: 2': 'Bureau / Department', 'Unnamed: 3': 'Contact Name', 'Unnamed: 4': 'Contact Email', 'Unnamed: 5': 'Summary of Use Case'})
doc_df= doc_df.drop([0,1])
doc_df= doc_df.reset_index()
doc_df= doc_df.drop(['index', 'Unnamed: 6'], axis=1)
doc_df["Agency"]= "Department of Commerce"
doc_df= doc_df[['Use Case Name', 'Summary of Use Case', 'Agency', 'Bureau / Department', 'Contact Name', 'Contact Email']]
doc_df.head()
#doc_df.reset_index(drop=True)
#doc_df.columns= doc_df.iloc[0]
#doc_df.drop(list(doc_df)[2], axis=1)
#doc_df.head()
# Out:
#                     Use Case Name  \
# 0                 B2B Matchmaking
# 1                   Chatbot Pilot
# 2     Consolidated Screening List
# 3          AD/CVD Self Initiation
# 4  Market Diversification Toolkit
#
#                                  Summary of Use Case                  Agency  \
# 0  The system's algorithms and AI technology qual...  Department of Commerce
# 1  Chatbot embedded into trade.gov to assist ITA ...  Department of Commerce
# 2  The Consolidated Screening List (CSL) is a lis...  Department of Commerce
# 3  The ADCVD program investigates allegations of ...  Department of Commerce
# 4  The Market Diversification Tool identifies pot...  Department of Commerce
#
#                         Bureau / Department     Contact Name  \
# 0  International Trade Administration (ITA)    Russell, Ryan
# 1  International Trade Administration (ITA)       Howard, Ed
# 2  International Trade Administration (ITA)  Kirwin, Patrick
# ...

# %%
# Department of Energy
doe_df = pd.read_csv(PARENT_DIR + "DOE_2023_AI_Use_Case_Inventory.csv")
doe_df= doe_df.rename(columns= {'Bureau/Department': 'Bureau / Department',
                                'Date Development/A cquisition Began': 'Date when Development and/or Acquisition began (if applicable)',
                                'Date Implemented' : 'Date Implemented (if applicable)',
                                'Consistent with EO 13960': 'Consistent with EO 13960?',
                                'Training Data Origin': 'Training Data Origins'

})
doe_df = doe_df[['Use Case Name', 'Summary of Use Case', 'Agency', 'Bureau / Department',
       'Stage of System Development Life Cycle',
       'Date when Development and/or Acquisition began (if applicable)', 'Date Implemented (if applicable)',
       'Contact Name', 'Contact Email', 'Developer Information',
       'Consistent with EO 13960?', 'AI Techniques Used',
       'Training Data Origins', 'Releaseable to the Public']]
doe_df.head()
# Out:
#                                        Use Case Name  \
# 0                               Groundwater Modeling
# 1  Memorandum of Understanding Between the US DOE...
# 2                             Soil Moisture Modeling
# 3                                               SMMM
# 4  Machine Learning for Autonomous Control of Sci...
#
#                                  Summary of Use Case  \
# 0  Groundwater modeling includes parameter estima...
# 1  The purpose of the Memorandum of Understanding...
# 2  Use multisource machine learning to model soil...
# 3  AI/ML is being used to evaluate measurements i...
# 4  BNL will work alongside SLAC, to implement ML ...
#
#                       Agency  \
# 0  U.S. Department of Energy
# 1  U.S. Department of Energy
# 2  U.S. Department of Energy
# 3  U.S. Department of Energy
# 4  U.S. Department of Energy
#
#                                 Bureau / Department  \
# 0                       Office of Legacy Management
# ...

# %%
# Department of Justice
doj_df= pd.read_csv(PARENT_DIR + "2021_department_of_justice_ai_use_case_inventory_justice.gov_.csv")
doj_df= doj_df.T
doj_df["Use Case Name"]= doj_df.index
doj_df.columns= doj_df.iloc[0]
doj_df= doj_df.reset_index()
doj_df= doj_df.drop(columns=['index'])
doj_df= doj_df.drop([0])
doj_df= doj_df.reset_index(drop=True)
doj_df= doj_df.rename_axis(None, axis=1)
doj_df= doj_df.rename(columns={'1A.\nAI use case name': 'Use Case Name',
                                 '1B.\nAgency with AI use case': 'Agency',
                                 'Provide a short summary (200 words max) of what the AI does. Include a high-level description of system inputs and outputs.': 'Summary of Use Case',
                                 '2A.\nLast Name, First Name': 'Contact Name',
                                 '1C.\nOffice with AI Use Case': 'Bureau / Department',
                                 '2B.\nEmail Address': 'Contact Email',
                                 '2C.\nAdditional point of contact name and email address': 'Additional Contact Name and Email',
                                 '4A.\nWhat stage of production is the AI in?': 'Stage of System Development Life Cycle',
                                 '4B.\nAdditional comments related to lifecycle stage.': 'Additional Life Cycle Comments',
                                 'What specific AI techniques were used?' : 'AI Techniques Used',
                                 '6A.\nDid/does the agency train this AI use case?': 'Agency Training Used',
                                 '6B.\nIf yes - Where did/does the training data originate?': 'Training Data Origins',
                                 '6C.\nIs the training data, the validation data, and/or test data included in the enterprise data inventory?': 'Included In Enterprise Inventory',
                                 '6D.\nIf data is publicly available, provide link.': 'Public Data Link',
                                 '7A.\nDoes the agency have access to the code associate with this AI use case?': 'Use Case Code Accessible',
                                 '7B.\nIf yes, is the code included in the agency source code inventory (e.g. Code.gov)?': 'Code Included In Agency Inventory',
                                 '7C.\nIf the source code is publicly available, provide the link.': 'Source Code Public Link',
                                 '7D.\nIs the agency able to conduct ongoing testing on the code?': 'Agency Able To Test Code',
                                 '7E.\nIs the agency able to monitor and/or audit performance?': 'Agency Able To Monitor/Audit',
                                 'Provide the name of the Information System (e.g. FISMA system name) associated with the AI use case.': 'FISMA System Name',
                                 '9A.\nShould this use case be withheld from the public inventory? If yes, the use case will only be shared in the internal government inventory.': 'Withhold Use Case',
                                 '9B.\nIf the answer to 9A is yes, provide an explanation (this explanation will be included in the internal government inventory).': 'Explanation To Withhold Use Case'
                                 })
#doj_df["Agency"]= "National Archives and Records Administration"
doj_df= doj_df[['Use Case Name',
                  'Summary of Use Case',
                  'Agency',
                  'Bureau / Department',
                  'Contact Name',
                  'Contact Email',
                  'Additional Contact Name and Email',
                  'Stage of System Development Life Cycle',
                  'Additional Life Cycle Comments',
                  'AI Techniques Used',
                  'Agency Training Used',
                  'Training Data Origins',
                  'Included In Enterprise Inventory',
                  'Public Data Link',
                  'Use Case Code Accessible',
                  'Code Included In Agency Inventory',
                  'Source Code Public Link',
                  'Agency Able To Test Code',
                  'Agency Able To Monitor/Audit',
                  'FISMA System Name',
                  'Withhold Use Case',
                  'Explanation To Withhold Use Case']]
doj_df.head()
# Out:
#                             Use Case Name  \
# 0       Drug Signature Program Algorithms
# 1        Complaint Lead Value Probability
# 2  Intelligent Records Consolidation Tool
# 3      Privileged Material Identification
#
#                                  Summary of Use Case                 Agency  \
# 0  DEA's Special Testing and Research Laboratory ...  Department of Justice
# 1  Threat Intake Processing System (TIPS) databas...  Department of Justice
# 2  The Office of Records Management Policy uses a...  Department of Justice
# 3  The application scans documents and looks for ...  Department of Justice
#
#                Bureau / Department      Contact Name  \
# 0  Drug Enforcement Administration  Bourque, Monique
# 1  Federal Bureau of Investigation  Bourque, Monique
# 2      Justice Management Division  Bourque, Monique
# 3                     Tax Division  Bourque, Monique
#
#                Contact Email Additional Contact Name and Email  \
# ...

# %%
# Department of the Treasury
dott_df= pd.read_csv(PARENT_DIR + "Treasury-AI-Use-Case-Inventory-May-2023.csv")
dott_df= dott_df.rename(columns={'AI Use Case Name': 'Use Case Name',
                                 'AI Use Case Summary': 'Summary of Use Case',
                                 "Production Stage": "Stage of System Development Life Cycle"})
dott_df["Agency"]= "U.S. Department of the Treasury"
dott_df= dott_df[['Use Case Name', 'Summary of Use Case', 'Agency', 'Stage of System Development Life Cycle']]
dott_df.head()
# Out:
#                                        Use Case Name  \
# 0  Inventory Item Replenishment MLR Modeling POC ...
# 1  Inventory Item Replenishment MLR Modeling Pilo...
# 2  Inventory Item Replenishment MLR Modeling POC ...
# 3                                Collection Chat Bot
# 4                               Collection Voice Bot
#
#                                  Summary of Use Case  \
# 0  The Bureau of Engraving and Printing wanted to...
# 1  The Bureau of Engraving and Printing wanted to...
# 2  The Bureau of Engraving and Printing wanted to...
# 3  The Natural Language Understanding (NLU) model...
# 4  The Nuance Natural Language Understanding (NLU...
#
#                             Agency Stage of System Development Life Cycle
# 0  U.S. Department of the Treasury            Development and Acquisition
# 1  U.S. Department of the Treasury            Development and Acquisition
# 2  U.S. Department of the Treasury            Development and Acquisition
# ...

# %%
nasa_df= pd.read_csv(PARENT_DIR + "2023_nasa_use_cases_for_ostp_may_2022_anonymous_tagged.csv")
nasa_df= nasa_df.drop([33,34])
nasa_df= nasa_df.drop(columns=['Unnamed: 10', 'Unnamed: 11'])
nasa_df["Agency"]= "NASA"
nasa_df= nasa_df.rename(columns= {'Stage of System Development Life\nCycle': "Stage of System Development Life Cycle",
       '(Optional) What specific AI techniques were used?': 'AI Techniques Used',
       '(Optional) Where did/does the training data originate?': 'Training Data Origins',
       '(Optional) Does the\nagency have access to the code associated': 'Use Case Code Accessible',
       '(Optional) If the source code is publicly available, provide link.': 'Source Code Public Link',
       '(Optional) Is the agency able to conduct ongoing testing\non the code?': 'Agency Able To Test Code',
       '(Optional) Is the\nagency able to monitor and/or' : 'Agency Able To Monitor/Audit'
})
nasa_df= nasa_df[['Use Case Name', 'Summary of Use Case', 'Agency', 'Bureau / Department',
       'Stage of System Development Life Cycle',
       'AI Techniques Used',
       'Training Data Origins',
       'Use Case Code Accessible',
       'Source Code Public Link',
       'Agency Able To Test Code',
       'Agency Able To Monitor/Audit']]
nasa_df.head()
# Out:
#                                        Use Case Name  \
# 0                                          AdaStress
# 1                                 Airplane detection
# 2  Application that provides bio-inspired solutio...
# 3                              ASPEN Mission Planner
# 4  Automatic Detection of Impervious Surfaces fro...
#
#                                  Summary of Use Case Agency  \
# 0  Testing complex systems often requires computa...   NASA
# 1  Deep learning-based airplane detection from hi...   NASA
# 2  PeTaL (the Periodic Table of Life) is an open ...   NASA
# 3  Based on AI techniques, ASPEN is a modular, re...   NASA
# 4  Uses a U-Net based architecture with VGG-19 as...   NASA
#
#             Bureau / Department Stage of System Development Life Cycle  \
# 0          Ames Research Center                                 In-use
# 1  Marshall Space Flight Center                                 In-use
# ...

# %%
# Master Dataset
masterAI_df= pd.concat([usda_df, ed_df, ssa_df, hhs_df, nara_df, usaid_df, opm_df, dhs_df,
                        doi_df, dot_df, gsa_df, va_df, dos_df, dol_df, epa_df, hud_df, doc_df,
                        doe_df, doj_df, dott_df, nasa_df], ignore_index=True)

# %%
# Column Count in Master DataFrame
masterAI_df.count().sort_values(ascending=False)
# Out:
# Agency                                                            756
# Use Case Name                                                     751
# Summary of Use Case                                               751
# Bureau / Department                                               673
# Developer Information                                             431
# Contact Email                                                     428
# Stage of System Development Life Cycle                            424
# Training Data Origins                                             349
# AI Techniques Used                                                346
# Consistent with EO 13960?                                         301
# Contact Name                                                      261
# Date when Development and/or Acquisition began (if applicable)    259
# Date Initiated (if applicable)                                    204
# ...

# %%
# Agency Groupby
agency_count= masterAI_df["Agency"].value_counts()
agency_count= agency_count.sort_values(ascending= False)
agency_count
# Out:
# U.S. Department of Energy                       183
# Health and Human Services                       163
# Department of Commerce                           52
# Department of Homeland Security                  41
# Department of Veterans Affairs                   40
# United States Department of Agriculture          39
# Department of the Interior                       38
# Department of State                              37
# NASA                                             33
# Department of Transportation                     31
# Department of Labor                              18
# U.S. Department of the Treasury                  17
# U.S. Agency for International Development        14
# Social Security Administration                   14
# General Services Administration                  12
# National Archives and Records Administration     11
# Office of Personnel Management                    4
# Department of Justice                             4
# ...

# %%
# HHS Agency groupby
hhs_count= masterAI_df.groupby(["HHS Agency"])["Agency"].count()
hhs_count= hhs_count.sort_values(ascending= False)
hhs_count
# Out:
# HHS Agency
# NIH                                               47
# FDA                                               44
# ASPR                                              25
# Centers for Medicare & Medicaid Services (CMS)    23
# CDC                                               19
# AHRQ                                               2
# OIG                                                2
# ACF                                                1
# Name: Agency, dtype: int64

# %%
# Bureau / Department Groupby
dept_count= masterAI_df.groupby(["Bureau / Department"])["Agency"].count()
dept_count= dept_count.sort_values(ascending= False)
dept_count.head(25)
# Out:
# Bureau / Department
# National Energy Technology Laboratory                                                             132
# National Oceanic and Atmospheric Administration (NOAA)                                             28
# USGS                                                                                               24
# Centers for Medicare & Medicaid Services (CMS): Centers for Medicare & Medicaid Services (CMS)     23
# REDACTED                                                                                           17
# NIH: National Institutes of Health (NIH) NLM                                                       14
# Fermi National Accelerator                                                                         14
# Customs and Border Protection                                                                      13
# Pacific Northwest National Laboratory                                                              12
# ...

# %%
# AI Technique Groupby
ai_count= masterAI_df.groupby(["AI Techniques Used"])["Agency"].count()
ai_count= ai_count.sort_values(ascending= False)
ai_count.head(25)
# Out:
# AI Techniques Used
# Other                                                                            31
# Artificial Intelligence                                                          26
# ["Machine Learning"]                                                             22
# REDACTED                                                                         17
# Big Data, Other                                                                  14
# Artificial Intelligence, Big Data, Neural Networks                               10
# Artificial Intelligence, Neural Networks                                         10
# Neural Networks, Other                                                            9
# ["Natural Language Processing"]                                                   8
# Machine Learning                                                                  8
# constraint-based heuristic search                                                 7
# ...

# %%
# Training Data Origins Groupby
trainingdata_count= masterAI_df.groupby(["Training Data Origins"])["Agency"].count()
trainingdata_count= trainingdata_count.sort_values(ascending= False)
trainingdata_count.head(25)
# Out:
# Training Data Origins
# Agency Generated                                                                                                                                                                           98
# Unknown                                                                                                                                                                                    94
# Agency generated                                                                                                                                                                           17
# REDACTED                                                                                                                                                                                   17
# experimental data, open-source                                                                                                                                                             14
# ...

# %%
# Stage of System Development Life Cycle Groupby
devstage_count= masterAI_df.groupby(["Stage of System Development Life Cycle"])["Agency"].count()
devstage_count= devstage_count.sort_values(ascending= False)
devstage_count.head(25)
# Out:
# Stage of System Development Life Cycle
# Operation and Maintenance                            89
# Development and Acquisition                          81
# Initiation                                           62
# Implementation                                       44
# In-use                                               27
# Operation and Management                             26
# Planned (not in production)                          21
# REDACTED                                             17
# In production: more than 1 year                       7
# Initiation                                            7
# Stage of Development  Operation and Maintenance       6
# In mission                                            6
# Development (not in production)                       6
# Stage of Development  Implementation                  5
# Stage of Development  Initiation                      5
# In production: less than six months                   2
# ...

# %%
# Generative QA Preprocessing
masterAI_df["text"]= masterAI_df["Agency"] + ", " + masterAI_df["Use Case Name"] + ", " + masterAI_df["Summary of Use Case"] + ", " + masterAI_df["Bureau / Department"] + ", " + masterAI_df["AI Techniques Used"] + ", " + masterAI_df["Training Data Origins"] + ", " + masterAI_df["Stage of System Development Life Cycle"]
masterAI_df= masterAI_df.fillna(0)
masterAI_df.to_csv(PARENT_DIR + "AIUseCases.csv")
